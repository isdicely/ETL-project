# %%
# Dependencies
import pandas as pd

# %%
# Import csv file into a data frame
csv_path = "Resources/bestsellers with categories.csv"
best_sellers_df1=pd.read_csv(csv_path)
best_sellers_df1
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Sort data frame by year (ascending) and set the index to the name of the best sellers
best_sellers_df2= best_sellers_df1.sort_values(by=['Year']).set_index("Name")

# %%
# Display the data frame
best_sellers_df2
# Out:
#                                                               Author  \
# Name
# I, Alex Cross                                        James Patterson
# Glenn Beck's Common Sense: The Case Against an ...        Glenn Beck
# The Last Lecture                                        Randy Pausch
# New Moon (The Twilight Saga)                         Stephenie Meyer
# Diary of a Wimpy Kid: The Last Straw (Book 3)            Jeff Kinney
# ...                                                              ...
# Guts                                                Raina Telgemeier
# The Subtle Art of Not Giving a F*ck: A Counteri...       Mark Manson
# The Silent Patient                                  Alex Michaelides
# Girl, Wash Your Face: Stop Believing the Lies A...     Rachel Hollis
# You Are a Badass: How to Stop Doubting Your Gre...       Jen Sincero
#
#                                                     User Rating  Reviews  \
# Name
# ...
